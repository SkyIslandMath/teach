# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import geopandas as gpd
import dask.dataframe as dd
import plotly.express as px

# %%
df=pd.read_csv('d://data/bison-PimaCounty_County_Arizona.csv',usecols=[9,
                13,16,20,21])

# %%
df.head(10)
# Out:
#     eventDate                   scientificName  \
# 0  2013-07-23               Phainopepla nitens
# 1  2013-08-01              Tyrannus verticalis
# 2  2009-09-25                  Spinus psaltria
# 3  2012-05-14             Myiarchus tyrannulus
# 4  2006-12-05                      Anas crecca
# 5  2006-12-06                      Anas crecca
# 6  2012-10-30                Actitis macularia
# 7  2015-05-04                   Cathartes aura
# 8  2013-07-23  Campylorhynchus brunneicapillus
# 9  2013-07-23                  Rallus limicola
#
#                                       ITIScommonName  decimalLatitude  \
# 0                       Phainopepla;Capulinero negro        32.243710
# 1    Western Kingbird;Tirano p?lido;tyran de l'ouest        31.885239
# 2                                   Lesser Goldfinch        31.934946
# 3         Brown-crested Flycatcher;Papamoscas tirano        32.280602
# 4  Eurasian Teal;Green-winged Teal;Cerceta ala ve...        32.337589
# ...

# %%
px.scatter_geo(df,lat='decimalLatitude',lon='decimalLongitude',hover_name='ITIScommonName')

# %%
species=df.groupby('ITIScommonName').count().reset_index()

# %%
 df[df['ITIScommonName'].str.contains('toad')==True]
# Out:
#           eventDate                  scientificName  \
# 42330    2013-05-12      Comandra umbellata pallida
# 331603   2006-09-02      Comandra umbellata pallida
# 954100   2016-03-08        Antirrhinum nuttallianum
# 976057   1973-04-27        Antirrhinum nuttallianum
# 977291   1979-04-01                  Linaria texana
# 977375   1973-04-07                  Linaria texana
# 989321   1998-04-11        Antirrhinum nuttallianum
# 989972   1998-09-14      Comandra umbellata pallida
# 1133666  1973-03-24                  Linaria texana
# 1175350  1973-04-27        Antirrhinum nuttallianum
# 1520634  2005-04-27      Comandra umbellata pallida
# 1542633  1953-04-25      Comandra umbellata pallida
# 1544837  1986-04-22      Comandra umbellata pallida
# 1544848  1963-09-25      Comandra umbellata pallida
# 1544850  1976-05-26      Comandra umbellata pallida
# 1544969  1979-07-24      Comandra umbellata pallida
# 1548853  1942-03-30                  Linaria texana
# ...

# %%
wren

# %%
wren.plot.scatter(x='decimalLongitude',y='decimalLatitude')
